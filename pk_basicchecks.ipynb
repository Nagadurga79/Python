# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\durga79\NOTEPAD_FILES\pk_movie_information.txt")

# %%
df
# Out:
#     Year                        Title                                 Role  \
# 0   1996  Akkada_Ammayi_Ikkada_Abbayi                     Mullapudi_Kalyan
# 1   1997              Gokulamlo_Seeta                         Pawan_Kalyan
# 2   1998                  Suswagatham                               Ganesh
# 3   1998                  Tholi_Prema                                 Balu
# 4   1999                     Thammudu                  Subramanyam/Subhash
# 5   2000                        Badri                                Badri
# 6   2001                        Kushi                               Siddhu
# 7   2003                       Johnny                               Johnny
# 8   2004              Gudumba_Shankar               Gudumba_Shankar/Kalyan
# 9   2004         Shankar_Dada_M.B.B.S                      Gudumba_Shankar
# 10  2005                         Balu                           Balu/Ghani
# ...

# %%
df.head()
# Out:
#    Year                        Title                 Role  Budget  Revenue  \
# 0  1996  Akkada_Ammayi_Ikkada_Abbayi     Mullapudi_Kalyan      33       33
# 1  1997              Gokulamlo_Seeta         Pawan_Kalyan      67       49
# 2  1998                  Suswagatham               Ganesh      33       11
# 3  1998                  Tholi_Prema                 Balu      45       38
# 4  1999                     Thammudu  Subramanyam/Subhash      85       48
#
#    No_of_songs  No_of_Fights         Result
# 0           10             7            Hit
# 1            4             3            Hit
# 2            7             8        Average
# 3            6             2  Above_Average
# 4            7             1        Average

# %%
df.tail()
# Out:
#     Year         Title                                 Role  Budget  Revenue  \
# 14  2008         Jalsa                          Sanjay_Sahu       5       72
# 15  2010          Puli                         Komaram_Puli      25       45
# 16  2011     Teen Maar      Arjun_Palwai/Michael_Velayudham      83       82
# 17  2011        Panjaa                                  Jai      70       50
# 18  2012  Gabbar_Singh  CI/Venkataratnam_Naidu/Gabbar_Singh      43       11
#
#     No_of_songs  No_of_Fights         Result
# 14            6             8        Average
# 15            2             9            Hit
# 16            3             6           Flop
# 17            3             6        Average
# 18            0             7  Above_Average

# %%
df.columns
# Out:
# Index(['Year', 'Title', 'Role', 'Budget', 'Revenue', 'No_of_songs',
#        'No_of_Fights', 'Result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year             int64
# Title           object
# Role            object
# Budget           int64
# Revenue          int64
# No_of_songs      int64
# No_of_Fights     int64
# Result          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          19 non-null     int64
#  1   Title         19 non-null     object
#  2   Role          19 non-null     object
#  3   Budget        19 non-null     int64
#  4   Revenue       19 non-null     int64
#  5   No_of_songs   19 non-null     int64
#  6   No_of_Fights  19 non-null     int64
#  7   Result        19 non-null     object
# dtypes: int64(5), object(3)
# memory usage: 1.3+ KB
